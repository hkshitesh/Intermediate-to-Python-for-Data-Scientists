# %% [markdown]
# <h1 style="color: #fcd805">Exercise: APIs</h1>
#
# 1. Every endpoint in the Star Wars API supports searching. Read the documentation at https://swapi.dev/documentation#search and see if you can search the database to find **Darth Vader's height**.

# %%
import requests

url = "https://swapi.dev/api/people/?search=darth"

response = requests.get(url)
response.raise_for_status()

# %%
darth = response.json()
darth["results"][0]["height"]
# Out:
# '202'

# %% [markdown]
# 2. Find the **endpoint** (i.e. the specific url) responsible for returning data about starships.
#
# Use this endpoint to search the database and find the Millennium Falcon.
#
# What is its **cargo capacity**?

# %%
url = "https://swapi.dev/api/starships?search=millennium"

response = requests.get(url)
response.raise_for_status()

# %%
falcon = response.json()
falcon["results"][0]["cargo_capacity"]
# Out:
# '100000'

# %% [markdown]
# 3. Every starship record contains links to its pilots. Find the characters who have piloted the Millennium Falcon and print their names.
#
# *Hint: you may need to make further API calls...!*

# %%
pilots = falcon["results"][0]["pilots"]

pilots
# Out:
# ['https://swapi.dev/api/people/13/',
#  'https://swapi.dev/api/people/14/',
#  'https://swapi.dev/api/people/25/',
#  'https://swapi.dev/api/people/31/']

# %%
for pilot in pilots:
    person_request = requests.get(pilot)
    person_request.raise_for_status()
    person = person_request.json()
    print(person["name"])
# Out:
# Chewbacca
# Han Solo
# Lando Calrissian
# Nien Nunb

# %% [markdown]
# <h1 style="color: #fcd805">Exercise: APIs and `pandas`</h1>
#
# We're going to explore a new API, the Gutendex (https://gutendex.com/).
#
# This is an API to access data about the Project Gutenberg catalogue. Project Gutenberg (https://www.gutenberg.org/) is an initiative to digitise works of literature.
#
# The url to retrieve all books is https://gutendex.com/books.
#
# 1. Look at the documentation on the website to figure out how to modify the url to get only books on the topic of horror.
#
# Call this url using `requests` to get a response.

# %%
book_response = requests.get("https://gutendex.com/books?topic=horror")

book_response.raise_for_status()

books_json = book_response.json()

books_json
# Out:
# {'count': 249,
#  'next': 'https://gutendex.com/books/?page=2&topic=horror',
#  'previous': None,
#  'results': [{'id': 84,
#    'title': 'Frankenstein; Or, The Modern Prometheus',
#    'authors': [{'name': 'Shelley, Mary Wollstonecraft',
#      'birth_year': 1797,
#      'death_year': 1851}],
#    'translators': [],
#    'subjects': ["Frankenstein's monster (Fictitious character) -- Fiction",
#     'Frankenstein, Victor (Fictitious character) -- Fiction',
#     'Gothic fiction',
#     'Horror tales',
#     'Monsters -- Fiction',
#     'Science fiction',
#     'Scientists -- Fiction'],
#    'bookshelves': ['Browsing: Culture/Civilization/Society',
#     'Browsing: Fiction',
#     'Browsing: Gender & Sexuality Studies',
#     'Browsing: Literature',
#     'Browsing: Science-Fiction & Fantasy',
#     'Gothic Fiction',
#     'Movie Books',
#     'Precursors of Science Fiction',
#     'Science Fiction by Women'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/84.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/84.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/84.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/84.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/84/pg84.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/84.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/84/pg84-h.zip'},
#    'download_count': 78467},
#   {'id': 5200,
#    'title': 'Metamorphosis',
#    'authors': [{'name': 'Kafka, Franz',
#      'birth_year': 1883,
#      'death_year': 1924}],
#    'translators': [{'name': 'Wyllie, David (Translator)',
#      'birth_year': None,
#      'death_year': None}],
#    'subjects': ['Metamorphosis -- Fiction', 'Psychological fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Browsing: Psychiatry/Psychology',
#     'Horror'],
#    'languages': ['en'],
#    'copyright': True,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/5200.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/5200/5200-h/5200-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/5200.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/5200.kf8.images',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/5200/5200-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/5200.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/5200/pg5200.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/5200/pg5200-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/5200.txt.utf-8'},
#    'download_count': 25124},
#   {'id': 345,
#    'title': 'Dracula',
#    'authors': [{'name': 'Stoker, Bram',
#      'birth_year': 1847,
#      'death_year': 1912}],
#    'translators': [],
#    'subjects': ['Dracula, Count (Fictitious character) -- Fiction',
#     'Epistolary fiction',
#     'Gothic fiction',
#     'Horror tales',
#     'Transylvania (Romania) -- Fiction',
#     'Vampires -- Fiction',
#     'Whitby (England) -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Browsing: Science-Fiction & Fantasy',
#     'Gothic Fiction',
#     'Horror',
#     'Movie Books',
#     'Mystery Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/345.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/345.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/345.kf8.images',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/345.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/345.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/345/pg345.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/345/pg345-h.zip'},
#    'download_count': 22060},
#   {'id': 43,
#    'title': 'The Strange Case of Dr. Jekyll and Mr. Hyde',
#    'authors': [{'name': 'Stevenson, Robert Louis',
#      'birth_year': 1850,
#      'death_year': 1894}],
#    'translators': [],
#    'subjects': ['Horror tales',
#     'London (England) -- Fiction',
#     'Multiple personality -- Fiction',
#     'Physicians -- Fiction',
#     'Psychological fiction',
#     'Science fiction',
#     'Self-experimentation in medicine -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Psychiatry/Psychology',
#     'Browsing: Science-Fiction & Fantasy',
#     'Horror',
#     'Movie Books',
#     'Precursors of Science Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/43.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/43.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/43.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/43.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/43/pg43.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/43/43-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/43.txt.utf-8'},
#    'download_count': 15401},
#   {'id': 8492,
#    'title': 'The King in Yellow',
#    'authors': [{'name': 'Chambers, Robert W. (Robert William)',
#      'birth_year': 1865,
#      'death_year': 1933}],
#    'translators': [],
#    'subjects': ['Horror tales, American',
#     'Short stories, American',
#     'United States -- Social life and customs -- 19th century -- Fiction'],
#    'bookshelves': ['Browsing: Culture/Civilization/Society',
#     'Browsing: Fiction',
#     'Browsing: Literature',
#     'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/8492.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/8492/8492-h/8492-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/8492.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/8492.kf8.images',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/8492/8492-8.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/8492.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/8492/pg8492.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/8492/pg8492-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/8492.txt.utf-8'},
#    'download_count': 9822},
#   {'id': 2148,
#    'title': 'The Works of Edgar Allan Poe — Volume 2',
#    'authors': [{'name': 'Poe, Edgar Allan',
#      'birth_year': 1809,
#      'death_year': 1849}],
#    'translators': [],
#    'subjects': ['American fiction -- 19th century',
#     'Fantasy fiction',
#     'Horror tales, American',
#     'Short stories'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: History - American',
#     'Browsing: Literature',
#     'Browsing: Science-Fiction & Fantasy',
#     'Detective Fiction',
#     'Gothic Fiction',
#     'Horror',
#     'Mystery Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/2148.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/2148.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/2148.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/2148.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/2148/pg2148.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/2148.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/2148/pg2148-h.zip'},
#    'download_count': 9013},
#   {'id': 10007,
#    'title': 'Carmilla',
#    'authors': [{'name': 'Le Fanu, Joseph Sheridan',
#      'birth_year': 1814,
#      'death_year': 1873}],
#    'translators': [],
#    'subjects': ['Vampires -- Fiction', 'Young women -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Gender & Sexuality Studies',
#     'Browsing: Literature',
#     'Gothic Fiction',
#     'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'application/octet-stream': 'https://www.gutenberg.org/cache/epub/10007/pg10007-h.zip',
#     'text/html': 'https://www.gutenberg.org/ebooks/10007.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/10007.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/10007.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/10007.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/10007/pg10007.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/10007.txt.utf-8'},
#    'download_count': 8776},
#   {'id': 41445,
#    'title': 'Frankenstein; Or, The Modern Prometheus',
#    'authors': [{'name': 'Shelley, Mary Wollstonecraft',
#      'birth_year': 1797,
#      'death_year': 1851}],
#    'translators': [],
#    'subjects': ["Frankenstein's monster (Fictitious character) -- Fiction",
#     'Frankenstein, Victor (Fictitious character) -- Fiction',
#     'Gothic fiction',
#     'Horror tales',
#     'Monsters -- Fiction',
#     'Science fiction',
#     'Scientists -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Gender & Sexuality Studies',
#     'Browsing: Literature',
#     'Browsing: Science-Fiction & Fantasy',
#     'Precursors of Science Fiction',
#     'Science Fiction by Women'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/41445.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/41445.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/41445.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/41445.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/41445/pg41445.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/41445/41445-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/41445.txt.utf-8'},
#    'download_count': 6993},
#   {'id': 6087,
#    'title': 'The Vampyre; a Tale',
#    'authors': [{'name': 'Polidori, John William',
#      'birth_year': 1795,
#      'death_year': 1821}],
#    'translators': [],
#    'subjects': ['Gothic fiction', 'Horror tales', 'Vampires -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Gothic Fiction',
#     'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/6087.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/6087/6087-h/6087-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/6087.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/6087.kf8.images',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/6087/6087-8.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/6087.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/6087/pg6087.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/6087/pg6087-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/6087.txt.utf-8'},
#    'download_count': 5354},
#   {'id': 42324,
#    'title': 'Frankenstein; Or, The Modern Prometheus',
#    'authors': [{'name': 'Shelley, Mary Wollstonecraft',
#      'birth_year': 1797,
#      'death_year': 1851}],
#    'translators': [],
#    'subjects': ["Frankenstein's monster (Fictitious character) -- Fiction",
#     'Frankenstein, Victor (Fictitious character) -- Fiction',
#     'Gothic fiction',
#     'Horror tales',
#     'Monsters -- Fiction',
#     'Science fiction',
#     'Scientists -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Science-Fiction & Fantasy',
#     'Precursors of Science Fiction',
#     'Science Fiction by Women'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/42324.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/42324/42324-h/42324-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/42324.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/42324.kf8.images',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/42324/42324-8.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/42324.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/42324/pg42324.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/42324.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/42324/pg42324-h.zip'},
#    'download_count': 4556},
#   {'id': 209,
#    'title': 'The Turn of the Screw',
#    'authors': [{'name': 'James, Henry',
#      'birth_year': 1843,
#      'death_year': 1916}],
#    'translators': [],
#    'subjects': ['Children -- Fiction',
#     'England -- Fiction',
#     'Ghost stories',
#     'Governesses -- Fiction',
#     'Psychological fiction'],
#    'bookshelves': ['Best Books Ever Listings',
#     'Browsing: Fiction',
#     'Browsing: Literature',
#     'Browsing: Psychiatry/Psychology',
#     'Gothic Fiction',
#     'Horror',
#     'Opera'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/209.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/209.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/209.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/209.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/209/pg209.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/209.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/209/pg209-h.zip'},
#    'download_count': 4165},
#   {'id': 121,
#    'title': 'Northanger Abbey',
#    'authors': [{'name': 'Austen, Jane',
#      'birth_year': 1775,
#      'death_year': 1817}],
#    'translators': [],
#    'subjects': ['Books and reading -- Fiction',
#     'England -- Fiction',
#     'England -- Social life and customs -- 19th century -- Fiction',
#     'Gentry -- England -- Fiction',
#     'Gothic fiction',
#     'Horror tales -- Appreciation -- Fiction',
#     'Love stories',
#     'Marriage -- Economic aspects -- Fiction',
#     'Satire',
#     'Young women -- Fiction'],
#    'bookshelves': ['Browsing: Culture/Civilization/Society',
#     'Browsing: Fiction',
#     'Browsing: Literature',
#     'Gothic Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/121.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/121.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/121.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/121.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/121/pg121.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/121/121-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/121.txt.utf-8'},
#    'download_count': 4119},
#   {'id': 2147,
#    'title': 'The Works of Edgar Allan Poe — Volume 1',
#    'authors': [{'name': 'Poe, Edgar Allan',
#      'birth_year': 1809,
#      'death_year': 1849}],
#    'translators': [],
#    'subjects': ['American fiction -- 19th century',
#     'Fantasy fiction',
#     'Horror tales, American',
#     'Poe, Edgar Allan, 1809-1849'],
#    'bookshelves': ['Browsing: Crime/Mystery',
#     'Browsing: Fiction',
#     'Browsing: Literature',
#     'Browsing: Science-Fiction & Fantasy',
#     'Detective Fiction',
#     'Horror',
#     'Mystery Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/2147.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/2147.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/2147.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/2147.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/2147/pg2147.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/2147.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/2147/pg2147-h.zip'},
#    'download_count': 3897},
#   {'id': 7849,
#    'title': 'The Trial',
#    'authors': [{'name': 'Kafka, Franz',
#      'birth_year': 1883,
#      'death_year': 1924}],
#    'translators': [{'name': 'Wyllie, David (Translator)',
#      'birth_year': None,
#      'death_year': None}],
#    'subjects': ['Allegories', 'Trials -- Fiction'],
#    'bookshelves': ['Best Books Ever Listings',
#     'Browsing: Fiction',
#     'Browsing: Literature',
#     'Horror'],
#    'languages': ['en'],
#    'copyright': True,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/7849.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/7849.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/7849.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/7849.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/7849/pg7849.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/7849/7849-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/7849.txt.utf-8'},
#    'download_count': 3560},
#   {'id': 696,
#    'title': 'The Castle of Otranto',
#    'authors': [{'name': 'Walpole, Horace',
#      'birth_year': 1717,
#      'death_year': 1797}],
#    'translators': [],
#    'subjects': ['Gothic fiction',
#     'Horror tales',
#     'Inheritance and succession -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Gothic Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/696.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/696.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/696.kf8.images',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/696/696-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/696.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/696/pg696.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/696/pg696-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/696.txt.utf-8'},
#    'download_count': 3442},
#   {'id': 375,
#    'title': 'An Occurrence at Owl Creek Bridge',
#    'authors': [{'name': 'Bierce, Ambrose',
#      'birth_year': 1842,
#      'death_year': 1913}],
#    'translators': [],
#    'subjects': ['Prisoners -- Fiction',
#     'Short stories',
#     'United States -- History -- Civil War, 1861-1865 -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: History - American',
#     'Browsing: Literature',
#     'Horror',
#     'US Civil War'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/375.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/375.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/375.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/375.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/375/pg375.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/375/375-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/375.txt.utf-8'},
#    'download_count': 3280},
#   {'id': 932,
#    'title': 'The Fall of the House of Usher',
#    'authors': [{'name': 'Poe, Edgar Allan',
#      'birth_year': 1809,
#      'death_year': 1849}],
#    'translators': [],
#    'subjects': ['Gothic fiction', 'Horror tales', 'Short stories'],
#    'bookshelves': ['Browsing: Fiction', 'Browsing: Literature', 'Movie Books'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/932.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/932/932-h/932-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/932.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/932.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/932.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/932/pg932.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/932/pg932-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/932.txt.utf-8'},
#    'download_count': 3107},
#   {'id': 1063,
#    'title': 'The Cask of Amontillado',
#    'authors': [{'name': 'Poe, Edgar Allan',
#      'birth_year': 1809,
#      'death_year': 1849}],
#    'translators': [],
#    'subjects': ['Horror tales, American', 'Revenge -- Fiction'],
#    'bookshelves': ['Browsing: Crime/Mystery',
#     'Browsing: Fiction',
#     'Browsing: Literature'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/1063.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/1063/1063-h/1063-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/1063.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/1063.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/1063.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/1063/pg1063.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/1063/pg1063-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/1063.txt.utf-8'},
#    'download_count': 2842},
#   {'id': 42,
#    'title': 'The Strange Case of Dr. Jekyll and Mr. Hyde',
#    'authors': [{'name': 'Stevenson, Robert Louis',
#      'birth_year': 1850,
#      'death_year': 1894}],
#    'translators': [],
#    'subjects': ['Horror tales',
#     'London (England) -- Fiction',
#     'Multiple personality -- Fiction',
#     'Physicians -- Fiction',
#     'Psychological fiction',
#     'Science fiction',
#     'Self-experimentation in medicine -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Browsing: Science-Fiction & Fantasy',
#     'Gothic Fiction',
#     'Horror',
#     'Movie Books',
#     'Precursors of Science Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/42.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/42.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/42.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/42.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/42/pg42.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/42/42-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/42.txt.utf-8'},
#    'download_count': 2802},
#   {'id': 12122,
#    'title': "The Monkey's Paw: The Lady of the Barge and Others, Part 2.",
#    'authors': [{'name': 'Jacobs, W. W. (William Wymark)',
#      'birth_year': 1863,
#      'death_year': 1943}],
#    'translators': [],
#    'subjects': ['Horror tales', 'Wishes -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Gothic Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/12122.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/12122.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/12122.kf8.images',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/12122.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/12122.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/12122/pg12122.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/12122/pg12122-h.zip'},
#    'download_count': 2726},
#   {'id': 1064,
#    'title': 'The Masque of the Red Death',
#    'authors': [{'name': 'Poe, Edgar Allan',
#      'birth_year': 1809,
#      'death_year': 1849}],
#    'translators': [],
#    'subjects': ['Horror tales, American'],
#    'bookshelves': ['Browsing: Fiction', 'Browsing: Literature'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/1064.html.images',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/1064/1064-h/1064-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/1064.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/1064.kf8.images',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/1064/1064-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/1064.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/1064/pg1064.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/1064/pg1064-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/1064.txt.utf-8'},
#    'download_count': 2351},
#   {'id': 175,
#    'title': 'The Phantom of the Opera',
#    'authors': [{'name': 'Leroux, Gaston',
#      'birth_year': 1868,
#      'death_year': 1927}],
#    'translators': [],
#    'subjects': ['Composers -- Fiction',
#     'French fiction -- Translations into English',
#     'Horror tales',
#     'Musical fiction',
#     'Opera -- Fiction',
#     'Paris (France) -- Fiction',
#     'Phantom of the Opera (Fictitious character) -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Browsing: Performing Arts/Film',
#     'Gothic Fiction',
#     'Movie Books',
#     'Opera'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/175.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/175/175-h/175-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/175.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/175.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/175.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/175/pg175.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/175/pg175-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/175.txt.utf-8'},
#    'download_count': 2262},
#   {'id': 10897,
#    'title': 'The Wendigo',
#    'authors': [{'name': 'Blackwood, Algernon',
#      'birth_year': 1869,
#      'death_year': 1951}],
#    'translators': [],
#    'subjects': ['Horror tales'],
#    'bookshelves': ['Browsing: Fiction', 'Browsing: Literature', 'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/10897.html.images',
#     'text/html; charset=iso-8859-1': 'https://www.gutenberg.org/files/10897/10897-h/10897-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/10897.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/10897.kf8.images',
#     'text/plain; charset=iso-8859-1': 'https://www.gutenberg.org/files/10897/10897-8.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/10897.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/10897/pg10897.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/10897/pg10897-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/10897.txt.utf-8'},
#    'download_count': 1995},
#   {'id': 68283,
#    'title': 'The call of Cthulhu',
#    'authors': [{'name': 'Lovecraft, H. P. (Howard Phillips)',
#      'birth_year': 1890,
#      'death_year': 1937}],
#    'translators': [],
#    'subjects': ['Cthulhu (Fictitious character) -- Fiction', 'Horror tales'],
#    'bookshelves': ['Browsing: Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/68283.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/68283.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/68283.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/68283.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/68283/pg68283.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/68283.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/68283/pg68283-h.zip'},
#    'download_count': 1710},
#   {'id': 10150,
#    'title': "Dracula's Guest",
#    'authors': [{'name': 'Stoker, Bram',
#      'birth_year': 1847,
#      'death_year': 1912}],
#    'translators': [],
#    'subjects': ['Gothic fiction', 'Horror tales', 'Short stories'],
#    'bookshelves': ['Browsing: Fiction', 'Browsing: Literature', 'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/10150.html.images',
#     'text/html; charset=utf-8': 'https://www.gutenberg.org/files/10150/10150-h/10150-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/10150.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/10150.kf8.images',
#     'text/plain; charset=utf-8': 'https://www.gutenberg.org/files/10150/10150-0.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/10150.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/10150/pg10150.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/10150/pg10150-h.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/10150.txt.utf-8'},
#    'download_count': 1511},
#   {'id': 25525,
#    'title': 'The Works of Edgar Allan Poe, The Raven Edition: Table Of Contents And Index Of The Five Volumes',
#    'authors': [{'name': 'Poe, Edgar Allan',
#      'birth_year': 1809,
#      'death_year': 1849}],
#    'translators': [],
#    'subjects': ['American fiction -- 19th century',
#     'Fantasy fiction',
#     'Horror tales, American',
#     'Indexes',
#     'Poe, Edgar Allan, 1809-1849',
#     'Short stories'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: History - American',
#     'Browsing: Literature'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/25525.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/25525.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/25525.kf8.images',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/25525.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/25525.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/25525/pg25525.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/25525/pg25525-h.zip'},
#    'download_count': 1353},
#   {'id': 11438,
#    'title': 'The Willows',
#    'authors': [{'name': 'Blackwood, Algernon',
#      'birth_year': 1869,
#      'death_year': 1951}],
#    'translators': [],
#    'subjects': ['Horror tales'],
#    'bookshelves': ['Browsing: Fiction', 'Browsing: Literature', 'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/11438.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/11438.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/11438.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/11438.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/11438/pg11438.cover.medium.jpg',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/11438.txt.utf-8',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/11438/pg11438-h.zip'},
#    'download_count': 1269},
#   {'id': 3268,
#    'title': 'The Mysteries of Udolpho',
#    'authors': [{'name': 'Radcliffe, Ann Ward',
#      'birth_year': 1764,
#      'death_year': 1823}],
#    'translators': [],
#    'subjects': ['Castles -- Fiction',
#     'Gothic fiction',
#     'Guardian and ward -- Fiction',
#     'Horror tales',
#     'Inheritance and succession -- Fiction',
#     'Italy -- Fiction',
#     'Orphans -- Fiction',
#     'Young women -- Fiction'],
#    'bookshelves': ['Browsing: Culture/Civilization/Society',
#     'Browsing: Fiction',
#     'Browsing: Literature',
#     'Gothic Fiction',
#     'Italy'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/3268.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/3268.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/3268.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/3268.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/3268/pg3268.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/3268/3268-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/3268.txt.utf-8'},
#    'download_count': 1168},
#   {'id': 389,
#    'title': 'The Great God Pan',
#    'authors': [{'name': 'Machen, Arthur',
#      'birth_year': 1863,
#      'death_year': 1947}],
#    'translators': [],
#    'subjects': ['Horror tales', 'Paranormal fiction'],
#    'bookshelves': ['Browsing: Fiction', 'Browsing: Literature', 'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/389.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/389.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/389.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/389.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/389/pg389.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/389/389-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/389.txt.utf-8'},
#    'download_count': 1160},
#   {'id': 2151,
#    'title': 'The Works of Edgar Allan Poe — Volume 5',
#    'authors': [{'name': 'Poe, Edgar Allan',
#      'birth_year': 1809,
#      'death_year': 1849}],
#    'translators': [],
#    'subjects': ['American fiction -- 19th century',
#     'American poetry',
#     'Fantasy fiction',
#     'Horror tales, American'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: History - American',
#     'Browsing: Literature',
#     'Horror',
#     'Mystery Fiction'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/2151.html.images',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/2151.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/2151.kf8.images',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/2151.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/2151/pg2151.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/files/2151/2151-0.zip',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/2151.txt.utf-8'},
#    'download_count': 1128},
#   {'id': 19797,
#    'title': 'Dracula',
#    'authors': [{'name': 'Stoker, Bram',
#      'birth_year': 1847,
#      'death_year': 1912}],
#    'translators': [],
#    'subjects': ['Dracula, Count (Fictitious character) -- Fiction',
#     'Epistolary fiction',
#     'Gothic fiction',
#     'Horror tales',
#     'Transylvania (Romania) -- Fiction',
#     'Vampires -- Fiction',
#     'Whitby (England) -- Fiction'],
#    'bookshelves': ['Browsing: Fiction',
#     'Browsing: Literature',
#     'Browsing: Science-Fiction & Fantasy',
#     'Horror',
#     'Movie Books'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Sound',
#    'formats': {'text/html': 'https://www.gutenberg.org/files/19797/19797-index.html',
#     'audio/ogg': 'https://www.gutenberg.org/files/19797/ogg/19797-01.ogg',
#     'audio/mp4': 'https://www.gutenberg.org/files/19797/m4b/19797-01.m4b',
#     'audio/mpeg': 'https://www.gutenberg.org/files/19797/mp3/19797-01.mp3',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/files/19797/19797.txt',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/19797.rdf'},
#    'download_count': 1099},
#   {'id': 23172,
#    'title': 'The Damned Thing: 1898, From "In the Midst of Life"',
#    'authors': [{'name': 'Bierce, Ambrose',
#      'birth_year': 1842,
#      'death_year': 1913}],
#    'translators': [],
#    'subjects': ['Horror tales', 'Short stories'],
#    'bookshelves': ['Browsing: Fiction', 'Browsing: Literature', 'Horror'],
#    'languages': ['en'],
#    'copyright': False,
#    'media_type': 'Text',
#    'formats': {'text/html': 'https://www.gutenberg.org/ebooks/23172.html.images',
#     'text/html; charset=us-ascii': 'https://www.gutenberg.org/files/23172/23172-h/23172-h.htm',
#     'application/epub+zip': 'https://www.gutenberg.org/ebooks/23172.epub3.images',
#     'application/x-mobipocket-ebook': 'https://www.gutenberg.org/ebooks/23172.kf8.images',
#     'text/plain; charset=us-ascii': 'https://www.gutenberg.org/ebooks/23172.txt.utf-8',
#     'application/rdf+xml': 'https://www.gutenberg.org/ebooks/23172.rdf',
#     'image/jpeg': 'https://www.gutenberg.org/cache/epub/23172/pg23172.cover.medium.jpg',
#     'application/octet-stream': 'https://www.gutenberg.org/cache/epub/23172/pg23172-h.zip'},
#    'download_count': 1034}]}

# %% [markdown]
# 2. Convert the response to a Python object. How many books are there in total that are tagged "horror"?
#
# _Hint: look at the response and find the right dictionary key to answer the question._

# %%
books_json["count"]
# Out:
# 249

# %% [markdown]
# 3. Find the right dictionary key within the returned result to retrieve the books as a list. Convert these to a `pandas` DataFrame.
#
# How many books were returned?

# %%
import pandas as pd

books = books_json["results"]

books_df = pd.DataFrame(books)
print(books_df.shape)
books_df.head()
# Out:
# (32, 11)
#      id                                        title  \
# 0    84      Frankenstein; Or, The Modern Prometheus
# 1  5200                                Metamorphosis
# 2   345                                      Dracula
# 3    43  The Strange Case of Dr. Jekyll and Mr. Hyde
# 4  8492                           The King in Yellow
#
#                                              authors  \
# 0  [{'name': 'Shelley, Mary Wollstonecraft', 'bir...
# 1  [{'name': 'Kafka, Franz', 'birth_year': 1883, ...
# 2  [{'name': 'Stoker, Bram', 'birth_year': 1847, ...
# 3  [{'name': 'Stevenson, Robert Louis', 'birth_ye...
# 4  [{'name': 'Chambers, Robert W. (Robert William...
#
#                                          translators  \
# 0                                                 []
# 1  [{'name': 'Wyllie, David (Translator)', 'birth...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                             subjects  \
# 0  [Frankenstein's monster (Fictitious character)...
# 1  [Metamorphosis -- Fiction, Psychological fiction]
# 2  [Dracula, Count (Fictitious character) -- Fict...
# 3  [Horror tales, London (England) -- Fiction, Mu...
# 4  [Horror tales, American, Short stories, Americ...
#
#                                          bookshelves languages  copyright  \
# 0  [Browsing: Culture/Civilization/Society, Brows...      [en]      False
# 1  [Browsing: Fiction, Browsing: Literature, Brow...      [en]       True
# 2  [Browsing: Fiction, Browsing: Literature, Brow...      [en]      False
# 3  [Browsing: Fiction, Browsing: Psychiatry/Psych...      [en]      False
# 4  [Browsing: Culture/Civilization/Society, Brows...      [en]      False
#
#   media_type                                            formats  \
# 0       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 1       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 2       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 3       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 4       Text  {'text/html': 'https://www.gutenberg.org/ebook...
#
#    download_count
# 0           78467
# 1           25124
# 2           22060
# 3           15401
# 4            9822

# %% [markdown]
# 4. Each request only retrieves 32 books, but we want all of them. Write a loop to go through all pages of the horror catalogue. In your loop you should:
#
# - request a new page of books by altering the url each time
# - take the results, save them into a Python object, then convert it to a `pandas` DataFrame
# - collect all these `pandas` DataFrames into a list
#
# At the end of your loop you should have a list of `pandas` DataFrames.

# %%
import time

# we know we have 233 books and 32 per page
# so we could explicitly loop a certain number of times
# or we could see that the JSON provides a "next" url
# which is a typical pattern to allow pagination
# so we could also keep going until that's None (i.e. blank)

book_dataframes = []

keep_going = True
page_url = "https://gutendex.com/books?topic=horror"

while keep_going:
    print(f"Attempting {page_url}...")
    books_page = requests.get(page_url)
    books_page.raise_for_status()
    
    books_json = books_page.json()
    
    # extract the book DataFrame
    books_df = pd.DataFrame(books_json["results"])
    book_dataframes.append(books_df)
    
    # and extract the next url unless we're done
    if books_json["next"]:
        page_url = books_json["next"]
    else:
        keep_going = False
    
    # a courtesy :-)
    time.sleep(0.5)

print("Done!")
# Out:
# Attempting https://gutendex.com/books?topic=horror...
# Attempting https://gutendex.com/books/?page=2&topic=horror...
# Attempting https://gutendex.com/books/?page=3&topic=horror...
# Attempting https://gutendex.com/books/?page=4&topic=horror...
# Attempting https://gutendex.com/books/?page=5&topic=horror...
# Attempting https://gutendex.com/books/?page=6&topic=horror...
# Attempting https://gutendex.com/books/?page=7&topic=horror...
# Attempting https://gutendex.com/books/?page=8&topic=horror...
# Done!

# %% [markdown]
# 5. Use the `.concat()` method to combine your DataFrames into a single DataFrame.
#
# How many horror books do you have in your data? Does the number match the count from question 2?

# %%
books_all = pd.concat(book_dataframes, ignore_index=True)
print(books_all.shape)
books_all.head()
# Out:
# (249, 11)
#      id                                        title  \
# 0    84      Frankenstein; Or, The Modern Prometheus
# 1  5200                                Metamorphosis
# 2   345                                      Dracula
# 3    43  The Strange Case of Dr. Jekyll and Mr. Hyde
# 4  8492                           The King in Yellow
#
#                                              authors  \
# 0  [{'name': 'Shelley, Mary Wollstonecraft', 'bir...
# 1  [{'name': 'Kafka, Franz', 'birth_year': 1883, ...
# 2  [{'name': 'Stoker, Bram', 'birth_year': 1847, ...
# 3  [{'name': 'Stevenson, Robert Louis', 'birth_ye...
# 4  [{'name': 'Chambers, Robert W. (Robert William...
#
#                                          translators  \
# 0                                                 []
# 1  [{'name': 'Wyllie, David (Translator)', 'birth...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                             subjects  \
# 0  [Frankenstein's monster (Fictitious character)...
# 1  [Metamorphosis -- Fiction, Psychological fiction]
# 2  [Dracula, Count (Fictitious character) -- Fict...
# 3  [Horror tales, London (England) -- Fiction, Mu...
# 4  [Horror tales, American, Short stories, Americ...
#
#                                          bookshelves languages  copyright  \
# 0  [Browsing: Culture/Civilization/Society, Brows...      [en]      False
# 1  [Browsing: Fiction, Browsing: Literature, Brow...      [en]       True
# 2  [Browsing: Fiction, Browsing: Literature, Brow...      [en]      False
# 3  [Browsing: Fiction, Browsing: Psychiatry/Psych...      [en]      False
# 4  [Browsing: Culture/Civilization/Society, Brows...      [en]      False
#
#   media_type                                            formats  \
# 0       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 1       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 2       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 3       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 4       Text  {'text/html': 'https://www.gutenberg.org/ebook...
#
#    download_count
# 0           78467
# 1           25124
# 2           22060
# 3           15401
# 4            9822

# %% [markdown]
# 6. How many downloads of horror books were there in total?

# %% [markdown]
# _Technically there is a media type which could be Sound, for audiobooks perhaps, but we'll class that under "download of a book"_

# %%
books_all["download_count"].sum()
# Out:
# 277005

# %% [markdown]
# 7. BONUS: Which author has the most books in the horror section?
#
# To answer this:
#
# - the `authors` column is a list of dictionaries. Figure out how to extract the *first* dictionary from each list and save these into a new column
# - use this new column to "unpack" the dictionary using `json_normalize`
# - use this "JSON normalised" data to calculate the most frequent author

# %%
import numpy as np

# write a custom function
def get_author(authors):
    if len(authors) >= 1:
        return authors[0]
    
    # if the authors list is blank, return NaN
    return np.nan

# use the function to extract a single author
# from the list of authors (which may be empty)
books_all["author"] = books_all["authors"].apply(get_author)

books_all.head()
# Out:
#      id                                        title  \
# 0    84      Frankenstein; Or, The Modern Prometheus
# 1  5200                                Metamorphosis
# 2   345                                      Dracula
# 3    43  The Strange Case of Dr. Jekyll and Mr. Hyde
# 4  8492                           The King in Yellow
#
#                                              authors  \
# 0  [{'name': 'Shelley, Mary Wollstonecraft', 'bir...
# 1  [{'name': 'Kafka, Franz', 'birth_year': 1883, ...
# 2  [{'name': 'Stoker, Bram', 'birth_year': 1847, ...
# 3  [{'name': 'Stevenson, Robert Louis', 'birth_ye...
# 4  [{'name': 'Chambers, Robert W. (Robert William...
#
#                                          translators  \
# 0                                                 []
# 1  [{'name': 'Wyllie, David (Translator)', 'birth...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                             subjects  \
# 0  [Frankenstein's monster (Fictitious character)...
# 1  [Metamorphosis -- Fiction, Psychological fiction]
# 2  [Dracula, Count (Fictitious character) -- Fict...
# 3  [Horror tales, London (England) -- Fiction, Mu...
# 4  [Horror tales, American, Short stories, Americ...
#
#                                          bookshelves languages  copyright  \
# 0  [Browsing: Culture/Civilization/Society, Brows...      [en]      False
# 1  [Browsing: Fiction, Browsing: Literature, Brow...      [en]       True
# 2  [Browsing: Fiction, Browsing: Literature, Brow...      [en]      False
# 3  [Browsing: Fiction, Browsing: Psychiatry/Psych...      [en]      False
# 4  [Browsing: Culture/Civilization/Society, Brows...      [en]      False
#
#   media_type                                            formats  \
# 0       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 1       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 2       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 3       Text  {'text/html': 'https://www.gutenberg.org/ebook...
# 4       Text  {'text/html': 'https://www.gutenberg.org/ebook...
#
#    download_count                                             author
# 0           78467  {'name': 'Shelley, Mary Wollstonecraft', 'birt...
# 1           25124  {'name': 'Kafka, Franz', 'birth_year': 1883, '...
# 2           22060  {'name': 'Stoker, Bram', 'birth_year': 1847, '...
# 3           15401  {'name': 'Stevenson, Robert Louis', 'birth_yea...
# 4            9822  {'name': 'Chambers, Robert W. (Robert William)...

# %%
pd.json_normalize(books_all["author"])["name"].value_counts().head(10)
# Out:
# name
# Poe, Edgar Allan                      26
# Lovecraft, H. P. (Howard Phillips)    17
# Howard, Robert E. (Robert Ervin)      11
# Stoker, Bram                          10
# Blackwood, Algernon                   10
# Doyle, Arthur Conan                    9
# Radcliffe, Ann Ward                    8
# Shelley, Mary Wollstonecraft           8
# Stevenson, Robert Louis                8
# Bierce, Ambrose                        7
# Name: count, dtype: int64

# %% [markdown]
# <h1 style="color: #fcd805">Exercise: web scraping</h1>
#
# Your turn to scrape some data from the bookshop!
#
# We're going to extract all the prices from the page and calculate the average book price.
#
# 1. Inspect the web page. What makes each book price element unique?
#
# _Hint: right-click and click Inspect to view the HTML behind an element on the page._

# %% [markdown]
# _Every price element is inside a `<p>` tag with class "price_color"_

# %% [markdown]
# 2. Use `BeautifulSoup` to select all the elements that show a book's price.

# %%
from bs4 import BeautifulSoup

bookstore_response = requests.get("http://books.toscrape.com/")

bookstore_response.raise_for_status()

soup = BeautifulSoup(bookstore_response.text, "html.parser")

price_tags = soup.select("p.price_color")
price_tags
# Out:
# [<p class="price_color">Â£51.77</p>,
#  <p class="price_color">Â£53.74</p>,
#  <p class="price_color">Â£50.10</p>,
#  <p class="price_color">Â£47.82</p>,
#  <p class="price_color">Â£54.23</p>,
#  <p class="price_color">Â£22.65</p>,
#  <p class="price_color">Â£33.34</p>,
#  <p class="price_color">Â£17.93</p>,
#  <p class="price_color">Â£22.60</p>,
#  <p class="price_color">Â£52.15</p>,
#  <p class="price_color">Â£13.99</p>,
#  <p class="price_color">Â£20.66</p>,
#  <p class="price_color">Â£17.46</p>,
#  <p class="price_color">Â£52.29</p>,
#  <p class="price_color">Â£35.02</p>,
#  <p class="price_color">Â£57.25</p>,
#  <p class="price_color">Â£23.88</p>,
#  <p class="price_color">Â£37.59</p>,
#  <p class="price_color">Â£51.33</p>,
#  <p class="price_color">Â£45.17</p>]

# %% [markdown]
# 3. Extract only the displayed text from these elements into a list.
#
# You should end up with a list of strings.

# %%
prices = [tag.text for tag in price_tags]
prices
# Out:
# ['Â£51.77',
#  'Â£53.74',
#  'Â£50.10',
#  'Â£47.82',
#  'Â£54.23',
#  'Â£22.65',
#  'Â£33.34',
#  'Â£17.93',
#  'Â£22.60',
#  'Â£52.15',
#  'Â£13.99',
#  'Â£20.66',
#  'Â£17.46',
#  'Â£52.29',
#  'Â£35.02',
#  'Â£57.25',
#  'Â£23.88',
#  'Â£37.59',
#  'Â£51.33',
#  'Â£45.17']

# %% [markdown]
# 4. Create a `pandas` `Series` from this list of strings by using `pd.Series`.

# %%
price_series = pd.Series(prices)

# %% [markdown]
# 5. Using your `pandas` knowledge, clean up these strings so they are just numeric prices, and convert the `Series` to be a numeric type.

# %%
price_series = price_series.str[2:].astype(float)
price_series
# Out:
# 0     51.77
# 1     53.74
# 2     50.10
# 3     47.82
# 4     54.23
# 5     22.65
# 6     33.34
# 7     17.93
# 8     22.60
# 9     52.15
# 10    13.99
# 11    20.66
# 12    17.46
# 13    52.29
# 14    35.02
# 15    57.25
# 16    23.88
# 17    37.59
# 18    51.33
# 19    45.17
# dtype: float64

# %% [markdown]
# 6. Now calculate the average price of books on the web page.

# %%
print(price_series.mean(), price_series.median())
# Out:
# 38.048500000000004 41.38
